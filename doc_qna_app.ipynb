# %%
pip install langchain openai streamlit chromadb unstructured python-docx PyMuPDF
# Out:
# Requirement already satisfied: langchain in c:\users\91751\anaconda3\lib\site-packages (0.3.26)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: openai in c:\users\91751\anaconda3\lib\site-packages (1.91.0)
# Requirement already satisfied: streamlit in c:\users\91751\anaconda3\lib\site-packages (1.37.1)
# Requirement already satisfied: chromadb in c:\users\91751\anaconda3\lib\site-packages (1.0.13)
# Requirement already satisfied: unstructured in c:\users\91751\anaconda3\lib\site-packages (0.18.1)
# Requirement already satisfied: python-docx in c:\users\91751\anaconda3\lib\site-packages (1.2.0)
# Requirement already satisfied: PyMuPDF in c:\users\91751\anaconda3\lib\site-packages (1.26.1)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in c:\users\91751\anaconda3\lib\site-packages (from langchain) (0.3.66)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\91751\anaconda3\lib\site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\91751\anaconda3\lib\site-packages (from langchain) (0.4.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\91751\anaconda3\lib\site-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\91751\anaconda3\lib\site-packages (from langchain) (2.0.34)
# Requirement already satisfied: requests<3,>=2 in c:\users\91751\anaconda3\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\91751\anaconda3\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\91751\anaconda3\lib\site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\91751\anaconda3\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\91751\anaconda3\lib\site-packages (from openai) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\91751\anaconda3\lib\site-packages (from openai) (0.10.0)
# Requirement already satisfied: sniffio in c:\users\91751\anaconda3\lib\site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\91751\anaconda3\lib\site-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\91751\anaconda3\lib\site-packages (from openai) (4.14.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\91751\anaconda3\lib\site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\91751\anaconda3\lib\site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\91751\anaconda3\lib\site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\91751\anaconda3\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\91751\anaconda3\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in c:\users\91751\anaconda3\lib\site-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\91751\anaconda3\lib\site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\91751\anaconda3\lib\site-packages (from streamlit) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\91751\anaconda3\lib\site-packages (from streamlit) (5.29.5)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\91751\anaconda3\lib\site-packages (from streamlit) (16.1.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\91751\anaconda3\lib\site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\91751\anaconda3\lib\site-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\91751\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\91751\anaconda3\lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\91751\anaconda3\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\91751\anaconda3\lib\site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: watchdog<5,>=2.1.5 in c:\users\91751\anaconda3\lib\site-packages (from streamlit) (4.0.1)
# Requirement already satisfied: build>=1.0.3 in c:\users\91751\anaconda3\lib\site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\91751\anaconda3\lib\site-packages (from chromadb) (1.4.1)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\91751\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.34.3)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\91751\anaconda3\lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\91751\anaconda3\lib\site-packages (from chromadb) (1.22.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\91751\anaconda3\lib\site-packages (from chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\91751\anaconda3\lib\site-packages (from chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\91751\anaconda3\lib\site-packages (from chromadb) (1.34.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\91751\anaconda3\lib\site-packages (from chromadb) (0.21.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\91751\anaconda3\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\91751\anaconda3\lib\site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\91751\anaconda3\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\91751\anaconda3\lib\site-packages (from chromadb) (1.73.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\91751\anaconda3\lib\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\91751\anaconda3\lib\site-packages (from chromadb) (0.9.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\91751\anaconda3\lib\site-packages (from chromadb) (33.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\91751\anaconda3\lib\site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\91751\anaconda3\lib\site-packages (from chromadb) (3.10.18)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\91751\anaconda3\lib\site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: chardet in c:\users\91751\anaconda3\lib\site-packages (from unstructured) (4.0.0)
# Requirement already satisfied: filetype in c:\users\91751\anaconda3\lib\site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: python-magic in c:\users\91751\anaconda3\lib\site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: lxml in c:\users\91751\anaconda3\lib\site-packages (from unstructured) (5.2.1)
# Requirement already satisfied: nltk in c:\users\91751\anaconda3\lib\site-packages (from unstructured) (3.9.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\91751\anaconda3\lib\site-packages (from unstructured) (4.12.3)
# Requirement already satisfied: emoji in c:\users\91751\anaconda3\lib\site-packages (from unstructured) (2.14.1)
# Requirement already satisfied: dataclasses-json in c:\users\91751\anaconda3\lib\site-packages (from unstructured) (0.6.7)
# Requirement already satisfied: python-iso639 in c:\users\91751\anaconda3\lib\site-packages (from unstructured) (2025.2.18)
# Requirement already satisfied: langdetect in c:\users\91751\anaconda3\lib\site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: rapidfuzz in c:\users\91751\anaconda3\lib\site-packages (from unstructured) (3.13.0)
# Requirement already satisfied: backoff in c:\users\91751\anaconda3\lib\site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: unstructured-client in c:\users\91751\anaconda3\lib\site-packages (from unstructured) (0.37.2)
# Requirement already satisfied: wrapt in c:\users\91751\anaconda3\lib\site-packages (from unstructured) (1.14.1)
# Requirement already satisfied: psutil in c:\users\91751\anaconda3\lib\site-packages (from unstructured) (5.9.0)
# Requirement already satisfied: python-oxmsg in c:\users\91751\anaconda3\lib\site-packages (from unstructured) (0.0.2)
# Requirement already satisfied: html5lib in c:\users\91751\anaconda3\lib\site-packages (from unstructured) (1.1)
# Requirement already satisfied: jinja2 in c:\users\91751\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: toolz in c:\users\91751\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: idna>=2.8 in c:\users\91751\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: pyproject_hooks in c:\users\91751\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\91751\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\91751\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: certifi in c:\users\91751\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\91751\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\91751\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\91751\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\91751\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\91751\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\91751\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.10.6)
# Requirement already satisfied: six>=1.9.0 in c:\users\91751\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\91751\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\91751\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\91751\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\91751\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\91751\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\91751\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.3)
# Requirement already satisfied: durationpy>=0.7 in c:\users\91751\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\91751\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (1.33)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\91751\anaconda3\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\91751\anaconda3\lib\site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: coloredlogs in c:\users\91751\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\91751\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: sympy in c:\users\91751\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.2)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\91751\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.0.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\91751\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.1 in c:\users\91751\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-proto==1.34.1 in c:\users\91751\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in c:\users\91751\anaconda3\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.55b1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\91751\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\91751\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\91751\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\91751\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\91751\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\91751\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\91751\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\91751\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\91751\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\91751\anaconda3\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.33.1)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\91751\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\91751\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\91751\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\91751\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\91751\anaconda3\lib\site-packages (from beautifulsoup4->unstructured) (2.5)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\91751\anaconda3\lib\site-packages (from dataclasses-json->unstructured) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\91751\anaconda3\lib\site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: webencodings in c:\users\91751\anaconda3\lib\site-packages (from html5lib->unstructured) (0.5.1)
# Requirement already satisfied: joblib in c:\users\91751\anaconda3\lib\site-packages (from nltk->unstructured) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\91751\anaconda3\lib\site-packages (from nltk->unstructured) (2024.9.11)
# Requirement already satisfied: olefile in c:\users\91751\anaconda3\lib\site-packages (from python-oxmsg->unstructured) (0.47)
# Requirement already satisfied: aiofiles>=24.1.0 in c:\users\91751\anaconda3\lib\site-packages (from unstructured-client->unstructured) (24.1.0)
# Requirement already satisfied: cryptography>=3.1 in c:\users\91751\anaconda3\lib\site-packages (from unstructured-client->unstructured) (43.0.0)
# Requirement already satisfied: nest-asyncio>=1.6.0 in c:\users\91751\anaconda3\lib\site-packages (from unstructured-client->unstructured) (1.6.0)
# Requirement already satisfied: pypdf>=4.0 in c:\users\91751\anaconda3\lib\site-packages (from unstructured-client->unstructured) (5.6.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\91751\anaconda3\lib\site-packages (from cryptography>=3.1->unstructured-client->unstructured) (1.17.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\91751\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\91751\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\91751\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: filelock in c:\users\91751\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\91751\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.6.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\91751\anaconda3\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\91751\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\91751\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain) (2.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\91751\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\91751\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\91751\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\91751\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pycparser in c:\users\91751\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.1->unstructured-client->unstructured) (2.21)
# Requirement already satisfied: pyreadline3 in c:\users\91751\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\91751\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)

# %%
import fitz  # PyMuPDF for PDFs
from docx import Document

def extract_text_from_pdf(file):
    doc = fitz.open(stream=file.read(), filetype="pdf")
    return "\n".join([page.get_text() for page in doc])

def extract_text_from_docx(file):
    doc = Document(file)
    return "\n".join([para.text for para in doc.paragraphs])

# %%
pip install -U langchain-community
# Out:
# Requirement already satisfied: langchain-community in c:\users\91751\anaconda3\lib\site-packages (0.3.26)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in c:\users\91751\anaconda3\lib\site-packages (from langchain-community) (0.3.66)
# Requirement already satisfied: langchain<1.0.0,>=0.3.26 in c:\users\91751\anaconda3\lib\site-packages (from langchain-community) (0.3.26)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\91751\anaconda3\lib\site-packages (from langchain-community) (2.0.34)
# Requirement already satisfied: requests<3,>=2 in c:\users\91751\anaconda3\lib\site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\91751\anaconda3\lib\site-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\91751\anaconda3\lib\site-packages (from langchain-community) (3.10.5)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\91751\anaconda3\lib\site-packages (from langchain-community) (8.2.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\91751\anaconda3\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\91751\anaconda3\lib\site-packages (from langchain-community) (2.6.1)
# Requirement already satisfied: langsmith>=0.1.125 in c:\users\91751\anaconda3\lib\site-packages (from langchain-community) (0.4.2)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\91751\anaconda3\lib\site-packages (from langchain-community) (0.4.1)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\91751\anaconda3\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\91751\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\91751\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\91751\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\91751\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\91751\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\91751\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.11.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\91751\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\91751\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\91751\anaconda3\lib\site-packages (from langchain<1.0.0,>=0.3.26->langchain-community) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\91751\anaconda3\lib\site-packages (from langchain<1.0.0,>=0.3.26->langchain-community) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\91751\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\91751\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\91751\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (4.14.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\91751\anaconda3\lib\site-packages (from langsmith>=0.1.125->langchain-community) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\91751\anaconda3\lib\site-packages (from langsmith>=0.1.125->langchain-community) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\91751\anaconda3\lib\site-packages (from langsmith>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\91751\anaconda3\lib\site-packages (from langsmith>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\91751\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (0.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\91751\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\91751\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\91751\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\91751\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\91751\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.0.1)
# Requirement already satisfied: anyio in c:\users\91751\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\91751\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\91751\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\91751\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\91751\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain-community) (2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\91751\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\91751\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\91751\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (0.4.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\91751\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)

# %%
pip install -U langchain
# Out:
# Requirement already satisfied: langchain in c:\users\91751\anaconda3\lib\site-packages (0.3.26)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in c:\users\91751\anaconda3\lib\site-packages (from langchain) (0.3.66)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\91751\anaconda3\lib\site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\91751\anaconda3\lib\site-packages (from langchain) (0.4.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\91751\anaconda3\lib\site-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\91751\anaconda3\lib\site-packages (from langchain) (2.0.34)
# Requirement already satisfied: requests<3,>=2 in c:\users\91751\anaconda3\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\91751\anaconda3\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\91751\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (8.2.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\91751\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\91751\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\91751\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (4.14.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\91751\anaconda3\lib\site-packages (from langsmith>=0.1.17->langchain) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\91751\anaconda3\lib\site-packages (from langsmith>=0.1.17->langchain) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\91751\anaconda3\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\91751\anaconda3\lib\site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\91751\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\91751\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\91751\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\91751\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\91751\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\91751\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\91751\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\91751\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.1)
# Requirement already satisfied: anyio in c:\users\91751\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\91751\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\91751\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\91751\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\91751\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain) (2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import Chroma  # or FAISS

def chunk_text(text):
    splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=100)
    return splitter.split_text(text)

def embed_and_store(chunks):
    embeddings = OpenAIEmbeddings()
    vectorstore = Chroma.from_texts(chunks, embeddings)
    return vectorstore

# %%
from langchain.chains import RetrievalQA
from langchain.chat_models import ChatOpenAI

# %%
def build_qa_chain(vectorstore):
    retriever = vectorstore.as_retriever(search_kwargs={"k": 4})
    llm = ChatOpenAI(model="gpt-4")
    return RetrievalQA.from_chain_type(llm=llm, retriever=retriever)

# %%
import streamlit as st

# %%
import streamlit as st
import fitz  # PyMuPDF for PDFs
from docx import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.embeddings import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma
from langchain.chains import RetrievalQA
from langchain.chat_models import ChatOpenAI
import tempfile
import os

# %%
st.set_page_config(page_title="Document QA GenAI", layout="centered")
st.title("📄 Document-based QA (GenAI)")

uploaded_file = st.file_uploader("Upload a PDF or Word Document", type=["pdf", "docx"])
question = st.text_input("Ask a question based on the document")

# %%
def extract_text_from_pdf(file_path):
    doc = fitz.open(file_path)
    return "\n".join([page.get_text() for page in doc])

def extract_text_from_docx(file_path):
    doc = Document(file_path)
    return "\n".join([para.text for para in doc.paragraphs])

# %%
def chunk_and_embed(text):
    splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
    chunks = splitter.split_text(text)
    embeddings = OpenAIEmbeddings()
    vectorstore = Chroma.from_texts(chunks, embeddings)
    return vectorstore

# %%
def run_qa_with_sources(vectorstore, question):
    retriever = vectorstore.as_retriever(search_kwargs={"k": 4})
    llm = ChatOpenAI(model="gpt-4", temperature=0)
    qa_chain = RetrievalQA.from_chain_type(
        llm=llm,
        retriever=retriever,
        return_source_documents=True
    )
    result = qa_chain(question)
    return result['result'], result['source_documents']

# %%
if uploaded_file and question:
    with tempfile.NamedTemporaryFile(delete=False) as tmp_file:
        tmp_file.write(uploaded_file.read())
        file_path = tmp_file.name

# %%
if uploaded_file and question:
    with tempfile.NamedTemporaryFile(delete=False) as tmp_file:
        tmp_file.write(uploaded_file.read())
        file_path = tmp_file.name

    if uploaded_file.type == "application/pdf":
        text = extract_text_from_pdf(file_path)
    else:
        text = extract_text_from_docx(file_path)

    os.unlink(file_path)

    with st.spinner("Processing document and generating answer..."):
        vectorstore = chunk_and_embed(text)
        answer, sources = run_qa_with_sources(vectorstore, question)

    st.success("Answer:")
    st.write(answer)

    st.info("🔍 Source Chunks Used:")
    for i, doc in enumerate(sources):
        st.markdown(f"**Chunk {i+1}:**\n```{doc.page_content.strip()}```")
